# %% [markdown]
# Matplotlib

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import numpy as np
# value x and y must be of same size
x = np.arange(1,10)
y = np.arange(11,20)

# %%
plt.scatter(x,y,c='r')
